# %% [markdown]
# <a href="https://colab.research.google.com/github/david-garza/final_project/blob/ETL/ETL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ETL

# %% [markdown]
# ## Beach Attributes File

# %%
# Import dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import psycopg2
from datetime import datetime
from getpass import getpass
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Bianca's path - Read beach_attributes from local gdrive location, MUST BE CHANGED TO MATCH YOUR FILE LOCATION!!!
beach_attr_df = pd.read_csv("/content/drive/MyDrive/Data/Beach/Beach_Attributes.csv")

# %%
# Examen the number of unique beaches in the data set
print(beach_attr_df["Beach Name"].unique())

# How many beaches are in galveston?
print(len(beach_attr_df["Beach Name"].unique()))
# Out:
# ['25th St.' '45th St.' '61st St.' 'Appfel Park' 'Caplen'
#  'Caplen/Crystal Beach' 'Clara St.' 'Dellanera Park' 'East Beach'
#  'Erman Pilsner Boat Ramp' 'Frank Carmona Beach'
#  'Galveston Island State Park' 'Galveston Island State Park Backside'
#  'Gilchrist East' 'Gilchrist West' 'Gulf Shores' 'Haney Park'
#  'High Island East' 'High Island West' 'Holiday' 'Indian Beach'
#  'Jamaica Beach' "O'Neil Rd." 'Pirates Beach' 'Rettilon Road'
#  'Rollover Pass East' 'Rollover Pass West' 'San Luis Pass' 'Sea Isle'
#  'Seadrift' 'Skyline Drive' 'Skyline Park' 'Spanish Grant/Bermuda Beach'
#  'Stewart Beach' 'Texas City Dike' 'West End']
# 36

# %%
# Investigate the number of unique values for each data column, columns with 1 value provide no information and can be dropped
beach_attr_df.nunique()
# Out:
# State                                    1
# Year                                    16
# Beach ID                                36
# Beach Name                              36
# County                                   1
# Beach Ownership/Beach Accessibility      1
# BeachLength (Mi)                        69
# Tier                                     3
# Start Latitude                          36
# Start Longitude                         36
# End Latitude                            36
# End Longitude                           36
# Waterbody Name                           1
# Waterbody Type                           2
# AdvisoryReportingFrequency(to EPA)       1
# AdvisoryReportingFrequencyUnits          1
# dtype: int64

# %%
# Investigate water type column, that is more then 36 beaches!
beach_attr_df["Waterbody Type"].value_counts()
# Out:
# Open Coast              469
# Sound, Bay, or Inlet     75
# Name: Waterbody Type, dtype: int64

# %%
# Number of years that beaches were reported
beach_attr_df["Year"].unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012,
#        2011, 2010, 2009, 2008, 2007])

# %%
# Create a list of columns that should be dropped, columns that have the same value
beach_attr_columns_to_drop = beach_attr_df.nunique()[beach_attr_df.nunique()==1].index
beach_attr_columns_to_drop
# Out:
# Index(['State', 'County', 'Beach Ownership/Beach Accessibility ',
#        'Waterbody Name', 'AdvisoryReportingFrequency(to EPA)',
#        'AdvisoryReportingFrequencyUnits'],
#       dtype='object')

# %%
# Drop the same value columns
beach_attr_df.drop(beach_attr_columns_to_drop,1,inplace=True)
beach_attr_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#    Year  Beach ID   Beach Name  BeachLength (Mi)  Tier  Start Latitude  \
# 0  2022  TX710697     25th St.              1.80     1       29.298146
# 1  2022  TX214299     45th St.              1.55     1       29.284667
# 2  2022  TX486021     61st St.              1.04     1       29.271922
# 3  2022  TX327206  Appfel Park              2.06     1       29.337451
# 4  2022  TX940700       Caplen              1.46     2       29.503046
#
#    Start Longitude  End Latitude  End Longitude Waterbody Type
# 0       -94.777565     29.284662     -94.794776     Open Coast
# 1       -94.794770     29.271917     -94.815865     Open Coast
# 2       -94.815859     29.264091     -94.830244     Open Coast
# 3       -94.733010     29.324250     -94.739129     Open Coast
# 4       -94.510477     29.494188     -94.532478     Open Coast

# %%
# Reporting beaches are added again each year, so drop year. we only care about the beach information
beach_attr_df.drop("Year",1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
# Determine the size and shape of the current dataframe after the year drop
print(beach_attr_df.shape)
beach_attr_df.head()
# Out:
# (544, 9)
#    Beach ID   Beach Name  BeachLength (Mi)  Tier  Start Latitude  \
# 0  TX710697     25th St.              1.80     1       29.298146
# 1  TX214299     45th St.              1.55     1       29.284667
# 2  TX486021     61st St.              1.04     1       29.271922
# 3  TX327206  Appfel Park              2.06     1       29.337451
# 4  TX940700       Caplen              1.46     2       29.503046
#
#    Start Longitude  End Latitude  End Longitude Waterbody Type
# 0       -94.777565     29.284662     -94.794776     Open Coast
# 1       -94.794770     29.271917     -94.815865     Open Coast
# 2       -94.815859     29.264091     -94.830244     Open Coast
# 3       -94.733010     29.324250     -94.739129     Open Coast
# 4       -94.510477     29.494188     -94.532478     Open Coast

# %%
# Now that year is gone, we can drop the duplicate rows, and should only have the unique beaches left
beach_attr_df.drop_duplicates(inplace=True)
beach_attr_df.shape
# Out:
# (71, 9)

# %%
# There are 71 rows of data, but there are only 36 beaches on Galveston Island! Something is wrong!
len(beach_attr_df["Beach ID"].unique())
# Out:
# 36

# %%
# Count how often a unique beach ID appears in the current data frame
beach_attr_df["Beach ID"].value_counts()
# Out:
# TX710697    2
# TX822495    2
# TX974690    2
# TX669225    2
# TX751320    2
# TX832087    2
# TX284256    2
# TX341767    2
# TX767833    2
# TX593160    2
# TX236175    2
# TX406100    2
# TX650612    2
# TX163187    2
# TX451421    2
# TX164090    2
# TX239942    2
# TX272864    2
# TX168454    2
# TX669733    2
# TX486021    2
# TX327206    2
# TX940700    2
# TX972853    2
# TX392019    2
# TX393353    2
# TX981462    2
# TX426780    2
# TX795287    2
# TX334226    2
# TX226514    2
# TX568423    2
# TX122528    2
# TX860495    2
# TX632189    2
# TX214299    1
# Name: Beach ID, dtype: int64

# %%
# Many beaches are still appearing twice in the data, why? Filter and display one beach ID to determine what is going on
beach_attr_df[beach_attr_df["Beach ID"]=="TX710697"]
# Out:
#      Beach ID Beach Name  BeachLength (Mi)  Tier  Start Latitude  \
# 0    TX710697   25th St.             1.800     1       29.298146
# 468  TX710697   25th St.             1.396     1       29.298146
#
#      Start Longitude  End Latitude  End Longitude Waterbody Type
# 0         -94.777565     29.284662     -94.794776     Open Coast
# 468       -94.777565     29.284662     -94.794776     Open Coast

# %%
# The beach that is returned is the beach on 25th Street. Upon inspection, all the data is the same except for the BeachLength column. Fix this by dropping the beachlengthy, beaches should be the same length year after year
beach_attr_df.drop("BeachLength (Mi)",1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
# Now that beachlength is dropped, the data should not have duplicates. Run drop_duplicates to remove the repeated rows of data
beach_attr_df.drop_duplicates(inplace=True)

# %%
# Now verify that each Beach ID only has one record
beach_attr_df["Beach ID"].value_counts()
# Out:
# TX710697    1
# TX214299    1
# TX239942    1
# TX974690    1
# TX669225    1
# TX751320    1
# TX832087    1
# TX284256    1
# TX341767    1
# TX822495    1
# TX767833    1
# TX236175    1
# TX406100    1
# TX650612    1
# TX163187    1
# TX451421    1
# TX164090    1
# TX593160    1
# TX272864    1
# TX669733    1
# TX981462    1
# TX486021    1
# TX327206    1
# TX940700    1
# TX972853    1
# TX392019    1
# TX393353    1
# TX168454    1
# TX632189    1
# TX795287    1
# TX334226    1
# TX226514    1
# TX568423    1
# TX122528    1
# TX860495    1
# TX426780    1
# Name: Beach ID, dtype: int64

# %%
# Check uniqueness of remaining columns
beach_attr_df.nunique()
# Out:
# Beach ID           36
# Beach Name         36
# Tier                3
# Start Latitude     36
# Start Longitude    36
# End Latitude       36
# End Longitude      36
# Waterbody Type      2
# dtype: int64

# %%
# Need to look up what is a Tier 1, 2, 3 beach. Print out the counts of the beach below
beach_attr_df["Tier"].value_counts()
# Out:
# 1    23
# 2     7
# 3     6
# Name: Tier, dtype: int64

# %%
# Check the number of different water types and what are they
beach_attr_df["Waterbody Type"].value_counts()
# Out:
# Open Coast              31
# Sound, Bay, or Inlet     5
# Name: Waterbody Type, dtype: int64

# %%
# Final table for load into a database. For database load, change column names, check data types match SQL data types, load into database table
beach_attr_df.head()
# Out:
#    Beach ID   Beach Name  Tier  Start Latitude  Start Longitude  End Latitude  \
# 0  TX710697     25th St.     1       29.298146       -94.777565     29.284662
# 1  TX214299     45th St.     1       29.284667       -94.794770     29.271917
# 2  TX486021     61st St.     1       29.271922       -94.815859     29.264091
# 3  TX327206  Appfel Park     1       29.337451       -94.733010     29.324250
# 4  TX940700       Caplen     2       29.503046       -94.510477     29.494188
#
#    End Longitude Waterbody Type
# 0     -94.794776     Open Coast
# 1     -94.815865     Open Coast
# 2     -94.830244     Open Coast
# 3     -94.739129     Open Coast
# 4     -94.532478     Open Coast

# %%
# Final row and column count
beach_attr_df.shape
# Out:
# (36, 8)

# %%
# check the datatypes
beach_attr_df.dtypes
# Out:
# Beach ID            object
# Beach Name          object
# Tier                 int64
# Start Latitude     float64
# Start Longitude    float64
# End Latitude       float64
# End Longitude      float64
# Waterbody Type      object
# dtype: object

# %% [markdown]
# ### ETL in preparation for loading the data into the Database

# %%
# Renaming the columns to match the database schema.
renamed_beach_attr_df = beach_attr_df.rename(columns={"Beach ID": "BeachID", "Beach Name":"BeachName", "Start Latitude": "StartLat",
                                                      "Start Longitude": "StartLong", "End Latitude":"EndLat", "End Longitude":"EndLong", "Waterbody Type":"WaterbodyType"})

renamed_beach_attr_df
# Out:
#      BeachID                             BeachName  Tier   StartLat  \
# 0   TX710697                              25th St.     1  29.298146
# 1   TX214299                              45th St.     1  29.284667
# 2   TX486021                              61st St.     1  29.271922
# 3   TX327206                           Appfel Park     1  29.337451
# 4   TX940700                                Caplen     2  29.503046
# 5   TX972853                  Caplen/Crystal Beach     2  29.494188
# 6   TX392019                             Clara St.     1  29.464994
# 7   TX393353                        Dellanera Park     1  29.242085
# 8   TX981462                            East Beach     2  29.324250
# 9   TX168454               Erman Pilsner Boat Ramp     3  29.369475
# 10  TX795287                   Frank Carmona Beach     2  29.232442
# 11  TX334226           Galveston Island State Park     1  29.195293
# 12  TX226514  Galveston Island State Park Backside     1  29.206505
# 13  TX568423                        Gilchrist East     2  29.532236
# 14  TX122528                        Gilchrist West     2  29.517307
# 15  TX860495                           Gulf Shores     1  29.454707
# 16  TX632189                            Haney Park     3  29.389655
# 17  TX669733                      High Island East     3  29.555610
# 18  TX272864                      High Island West     3  29.543206
# 19  TX593160                               Holiday     2  29.447543
# 20  TX239942                          Indian Beach     1  29.176498
# 21  TX974690                         Jamaica Beach     1  29.182981
# 22  TX669225                            O'Neil Rd.     1  29.439180
# 23  TX751320                         Pirates Beach     1  29.211276
# 24  TX832087                         Rettilon Road     1  29.396868
# 25  TX284256                    Rollover Pass East     1  29.511797
# 26  TX341767                    Rollover Pass West     1  29.506768
# 27  TX822495                         San Luis Pass     1  29.125977
# 28  TX767833                              Sea Isle     1  29.157639
# 29  TX236175                              Seadrift     1  29.480982
# 30  TX406100                         Skyline Drive     3  29.445647
# 31  TX650612                          Skyline Park     3  29.421600
# 32  TX163187           Spanish Grant/Bermuda Beach     1  29.225590
# 33  TX451421                         Stewart Beach     1  29.307157
# 34  TX164090                       Texas City Dike     1  29.389612
# 35  TX426780                              West End     1  29.430352
#
#     StartLong     EndLat    EndLong         WaterbodyType
# 0  -94.777565  29.284662 -94.794776            Open Coast
# 1  -94.794770  29.271917 -94.815865            Open Coast
# 2  -94.815859  29.264091 -94.830244            Open Coast
# 3  -94.733010  29.324250 -94.739129            Open Coast
# 4  -94.510477  29.494188 -94.532478            Open Coast
# 5  -94.532478  29.480985 -94.565257            Open Coast
# 6  -94.602679  29.454705 -94.625401            Open Coast
# 7  -94.868973  29.232450 -94.886528            Open Coast
# 8  -94.739123  29.307163 -94.765163            Open Coast
# 9  -94.750954  29.367046 -94.754748            Open Coast
# 10 -94.886530  29.225588 -94.897640            Open Coast
# 11 -94.948765  29.182981 -94.969426            Open Coast
# 12 -94.950650  29.193209 -94.977587  Sound, Bay, or Inlet
# 13 -94.432993  29.517307 -94.473127            Open Coast
# 14 -94.473127  29.511802 -94.487145            Open Coast
# 15 -94.625401  29.447545 -94.640508            Open Coast
# 16 -94.885453  29.386909 -94.886637  Sound, Bay, or Inlet
# 17 -94.370592  29.543203 -94.403804            Open Coast
# 18 -94.403799  29.532229 -94.432999            Open Coast
# 19 -94.640508  29.439180 -94.656535            Open Coast
# 20 -94.980493  29.157642 -95.011543            Open Coast
# 21 -94.969426  29.176498 -94.980493            Open Coast
# 22 -94.656532  29.430347 -94.672240            Open Coast
# 23 -94.921726  29.195290 -94.948765            Open Coast
# 24 -94.713310  29.367899 -94.732729            Open Coast
# 25 -94.487153  29.506899 -94.499180            Open Coast
# 26 -94.500215  29.503046 -94.510480            Open Coast
# 27 -95.062029  29.085638 -95.117245            Open Coast
# 28 -95.011542  29.125974 -95.062028            Open Coast
# 29 -94.565260  29.464991 -94.602676            Open Coast
# 30 -94.916604  29.435381 -94.896200  Sound, Bay, or Inlet
# 31 -94.888719  29.391283 -94.886855  Sound, Bay, or Inlet
# 32 -94.897638  29.211276 -94.921726            Open Coast
# 33 -94.765162  29.298141 -94.777570            Open Coast
# 34 -94.883575  29.365534 -94.810022  Sound, Bay, or Inlet
# 35 -94.672240  29.396866 -94.713313            Open Coast

# %% [markdown]
# ## Water Quality File

# %%
# Bianca's path loading the data.
water_quality_df = pd.read_csv("/content/drive/MyDrive/Data/Beach/Water_Quality_Report.csv")
water_quality_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   State Code  Year Beach ID(Def.) Beach Name(Def.) StationID(Def.)  \
# 0         TX  2021       TX974690    Jamaica Beach          GAL014
# 1         TX  2021       TX974690    Jamaica Beach          GAL014
# 2         TX  2021       TX974690    Jamaica Beach          GAL014
# 3         TX  2021       TX974690    Jamaica Beach          GAL014
# 4         TX  2021       TX974690    Jamaica Beach          GAL014
#
#    Station Name (Def.) CountyName(Def.)       Identifier(Def.)  \
# 0  Jamaica Beach South        GALVESTON  GAL014_20211227_90752
# 1  Jamaica Beach South        GALVESTON  GAL014_20211227_90752
# 2  Jamaica Beach South        GALVESTON  GAL014_20211215_90599
# 3  Jamaica Beach South        GALVESTON  GAL014_20211215_90599
# 4  Jamaica Beach South        GALVESTON  GAL014_20211201_90435
#
#   StartDate(Def.) StartTime(Def.)  ... ActivityDepthValue(Def.)  \
# 0       27-DEC-21     09:00:00 AM  ...                        2
# 1       27-DEC-21     09:00:00 AM  ...                        2
# 2       15-DEC-21     09:00:00 AM  ...                        2
# 3       15-DEC-21     09:00:00 AM  ...                        2
# 4       01-DEC-21     09:00:00 AM  ...                        2
#
#   ActivityDepthUnitCode(Def.) ResultAnalyticalMethodIdentifier Context(Def.)  \
# 0                          ft                                        21TXBCH
# 1                          ft                                        21TXBCH
# 2                          ft                                        21TXBCH
# 3                          ft                                        21TXBCH
# 4                          ft                                        21TXBCH
#
#    ResultAnalyticalMethodIdentifier(Def.)  ResultAnalyticalMethodName(Def.)  \
# 0                                   19299                        ENTEROLERT
# 1                                   19299                        ENTEROLERT
# 2                                   19299                        ENTEROLERT
# 3                                   19299                        ENTEROLERT
# 4                                   19299                        ENTEROLERT
#
#   Sample CollectionMethod Identifier(Def.)  \
# 0                               SPL_WTRGRB
# 1                               SPL_WTRGRB
# 2                               SPL_WTRGRB
# 3                               SPL_WTRGRB
# 4                               SPL_WTRGRB
#
#    Sample Collection Method Name(Def.)  Field Gear(Def.)  \
# 0                    Sample Water Grab      Water Bottle
# 1                    Sample Water Grab      Water Bottle
# 2                    Sample Water Grab      Water Bottle
# 3                    Sample Water Grab      Water Bottle
# 4                    Sample Water Grab      Water Bottle
#
#   AnalysisDateTime(Def.) DetectionQuantitationLimit(Def.)
# 0                    NaN                                -
# 1                    NaN                                -
# 2                    NaN                                -
# 3                    NaN                                -
# 4                    NaN                                -
#
# [5 rows x 27 columns]

# %%
# Calculate number of rows and columns of raw data frame
water_quality_df.shape
# Out:
# (42540, 27)

# %%
# Deterine which columns have no data, same value, no values, etc
water_quality_df.nunique()
# Out:
# State Code                                            1
# Year                                                 15
# Beach ID(Def.)                                       23
# Beach Name(Def.)                                     23
# StationID(Def.)                                      52
# Station Name (Def.)                                  52
# CountyName(Def.)                                      1
# Identifier(Def.)                                  28575
# StartDate(Def.)                                    1988
# StartTime(Def.)                                      41
# ZoneCode(Def.)                                        2
# ActivityTypeCode(Def.)                                1
# CharacteristicName(Def.)                              1
# Result ValueText(Def.)                                0
# ResultValue(Def.)                                  3006
# ResultMeasureUnit                                     3
# Result Comment(Def.)                                  0
# ActivityDepthValue(Def.)                              1
# ActivityDepthUnitCode(Def.)                           1
# ResultAnalyticalMethodIdentifier Context(Def.)        1
# ResultAnalyticalMethodIdentifier(Def.)                5
# ResultAnalyticalMethodName(Def.)                      3
# Sample CollectionMethod Identifier(Def.)              1
# Sample Collection Method Name(Def.)                   1
# Field Gear(Def.)                                      1
# AnalysisDateTime(Def.)                                0
# DetectionQuantitationLimit(Def.)                      1
# dtype: int64

# %%
# Create a list of the columns that have no useful data
water_quality_columns_to_drop =water_quality_df.nunique()[(water_quality_df.nunique()==1) | (water_quality_df.nunique()==0)].index

# %%
# Drop the useless data columns from the data frame
water_quality_df.drop(water_quality_columns_to_drop,1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
# Review the new data frame. This is the data frame to load into database. Still needs, update column names, format StartDate to standard format.
water_quality_df.head()
# Out:
#    Year Beach ID(Def.) Beach Name(Def.) StationID(Def.)  Station Name (Def.)  \
# 0  2021       TX974690    Jamaica Beach          GAL014  Jamaica Beach South
# 1  2021       TX974690    Jamaica Beach          GAL014  Jamaica Beach South
# 2  2021       TX974690    Jamaica Beach          GAL014  Jamaica Beach South
# 3  2021       TX974690    Jamaica Beach          GAL014  Jamaica Beach South
# 4  2021       TX974690    Jamaica Beach          GAL014  Jamaica Beach South
#
#         Identifier(Def.) StartDate(Def.) StartTime(Def.) ZoneCode(Def.)  \
# 0  GAL014_20211227_90752       27-DEC-21     09:00:00 AM            CDT
# 1  GAL014_20211227_90752       27-DEC-21     09:00:00 AM            CDT
# 2  GAL014_20211215_90599       15-DEC-21     09:00:00 AM            CDT
# 3  GAL014_20211215_90599       15-DEC-21     09:00:00 AM            CDT
# 4  GAL014_20211201_90435       01-DEC-21     09:00:00 AM            CDT
#
#    ResultValue(Def.) ResultMeasureUnit ResultAnalyticalMethodIdentifier(Def.)  \
# 0               7.94         MPN/100ml                                  19299
# 1              20.00         MPN/100ml                                  19299
# 2               6.30         MPN/100ml                                  19299
# 3               5.00         MPN/100ml                                  19299
# 4               7.07         MPN/100ml                                  19299
#
#   ResultAnalyticalMethodName(Def.)
# 0                       ENTEROLERT
# 1                       ENTEROLERT
# 2                       ENTEROLERT
# 3                       ENTEROLERT
# 4                       ENTEROLERT

# %%
# Check the number of rows and columns of the "cleaned" data frame
water_quality_df.shape
# Out:
# (42540, 13)

# %%
# Inspect the number of unique values for each remaining column, inspect any that might be weird, shouldn't be unique etc.
water_quality_df.nunique()
# Out:
# Year                                         15
# Beach ID(Def.)                               23
# Beach Name(Def.)                             23
# StationID(Def.)                              52
# Station Name (Def.)                          52
# Identifier(Def.)                          28575
# StartDate(Def.)                            1988
# StartTime(Def.)                              41
# ZoneCode(Def.)                                2
# ResultValue(Def.)                          3006
# ResultMeasureUnit                             3
# ResultAnalyticalMethodIdentifier(Def.)        5
# ResultAnalyticalMethodName(Def.)              3
# dtype: int64

# %%
# Examen start times.
water_quality_df["StartTime(Def.)"].value_counts()
# Out:
# 09:00:00 AM    26510
# 08:00:00 AM     6431
# 07:00:00 AM     3892
# 06:00:00 AM     1944
# 10:00:00 AM     1236
# 08:30:00 AM      808
# 09:30:00 AM      653
# 11:00:00 AM      363
# 05:00:00 AM      286
# 07:30:00 AM      208
# 12:00:00 PM       80
# 10:30:00 AM       57
# 01:00:00 PM       21
# 06:30:00 AM        7
# 11:30:00 AM        6
# 07:40:00 AM        4
# 07:50:00 AM        3
# 02:00:00 PM        3
# 05:30:00 AM        3
# 10:15:00 AM        2
# 08:08:00 AM        2
# 03:00:00 PM        2
# 09:42:00 AM        1
# 09:45:00 AM        1
# 09:35:00 AM        1
# 09:33:00 AM        1
# 10:25:00 AM        1
# 09:06:00 AM        1
# 09:09:00 AM        1
# 09:26:00 AM        1
# 09:20:00 AM        1
# 09:15:00 AM        1
# 09:48:00 AM        1
# 09:03:00 AM        1
# 12:45:00 PM        1
# 09:51:00 AM        1
# 10:05:00 AM        1
# 10:07:00 AM        1
# 10:10:00 AM        1
# 10:02:00 AM        1
# 09:38:00 AM        1
# Name: StartTime(Def.), dtype: int64

# %%
# These units need to be all the same. They many not be needed for model training. Keep for our records. Units are the same unit, see website in the next markdown cell for more information
water_quality_df["ResultMeasureUnit"].value_counts()
# Out:
# MPN/100ml    23186
# cfu/100ml    16175
# CFU           3179
# Name: ResultMeasureUnit, dtype: int64

# %% [markdown]
# Note measurement units, they are the same units. https://www.researchgate.net/post/Is_there_a_way_to_convert_MPN_most_probable_number_to_CFU_colony_forming_unit#:~:text=The%20simple%20answer%20is%20that,is%20equal%20to%20one%20CFU.

# %%
# what is zoneCode? Appears to indicate if time is winter or summer time
water_quality_df["ZoneCode(Def.)"].value_counts()
# Out:
# CDT    36100
# CST     6440
# Name: ZoneCode(Def.), dtype: int64

# %% [markdown]
# ### Converting necessary Datatypes

# %%
# Convert the column 'StartDate(Def.)' from object to datetime.
water_quality_df["Date"]=water_quality_df["StartDate(Def.)"].apply(lambda x:datetime.strptime(x,"%d-%b-%y"))

# Shift column "Date" to first position
first_column = water_quality_df.pop("Date")

# Insert column using insert(position,column_name,first_column) function
water_quality_df.insert(0, "Date", first_column)

# Drop the old column "StartDate(Def.)", which is now replaced by the column "Date".
water_quality_df = water_quality_df.drop(columns=["StartDate(Def.)"])

water_quality_df.head(2)
# Out:
#         Date  Year Beach ID(Def.) Beach Name(Def.) StationID(Def.)  \
# 0 2021-12-27  2021       TX974690    Jamaica Beach          GAL014
# 1 2021-12-27  2021       TX974690    Jamaica Beach          GAL014
#
#    Station Name (Def.)       Identifier(Def.) StartTime(Def.) ZoneCode(Def.)  \
# 0  Jamaica Beach South  GAL014_20211227_90752     09:00:00 AM            CDT
# 1  Jamaica Beach South  GAL014_20211227_90752     09:00:00 AM            CDT
#
#    ResultValue(Def.) ResultMeasureUnit ResultAnalyticalMethodIdentifier(Def.)  \
# 0               7.94         MPN/100ml                                  19299
# 1              20.00         MPN/100ml                                  19299
#
#   ResultAnalyticalMethodName(Def.)
# 0                       ENTEROLERT
# 1                       ENTEROLERT

# %%
# DateTime.ParseExact(
#     "2/22/2015 9:54:02 PM",
#     "M/dd/yyyy h:mm:ss tt", 
#     CultureInfo.InvariantCulture
#)

# %%
# # Convert the column "StartTime(Def.)"" from object to datetime.
# water_quality_df["Time"]=water_quality_df["StartTime(Def.)"].apply(lambda x:datetime.strptime(x,"%H:%M:%S %tt"))
# water_quality_df.head(2)

# %%
# Check the datatypes to make sure the datime conversion was successful.
water_quality_df.dtypes
# Out:
# Date                                      datetime64[ns]
# Year                                               int64
# Beach ID(Def.)                                    object
# Beach Name(Def.)                                  object
# StationID(Def.)                                   object
# Station Name (Def.)                               object
# Identifier(Def.)                                  object
# StartTime(Def.)                                   object
# ZoneCode(Def.)                                    object
# ResultValue(Def.)                                float64
# ResultMeasureUnit                                 object
# ResultAnalyticalMethodIdentifier(Def.)            object
# ResultAnalyticalMethodName(Def.)                  object
# dtype: object

# %% [markdown]
# ### Renaming Columns to match database schema.

# %%
# Renaming the columns to match the database schema.
renamed_water_quality_df = water_quality_df .rename(columns={"Beach ID(Def.)": "BeachID", "Beach Name(Def.)": "BeachName",
                                                             "StationID(Def.)":"StationID", "Station Name (Def.)":"StationName",
                                                             "Identifier(Def.)":"Identifier", "StartTime(Def.)":"StartTime", "ZoneCode(Def.)":"ZoneCode",
                                                             "ResultValue(Def.)":"BacteriaCount", "ResultMeasureUnit":"ResultMeasureUnit",
                                                             "ResultAnalyticalMethodIdentifier(Def.)":"ResultAnalyticalMethodIdentifier",
                                                             "ResultAnalyticalMethodName(Def.)":"ResultAnalyticalMethodName"})
                                                         
                                                    

renamed_water_quality_df
# Out:
#             Date  Year   BeachID      BeachName StationID  \
# 0     2021-12-27  2021  TX974690  Jamaica Beach    GAL014
# 1     2021-12-27  2021  TX974690  Jamaica Beach    GAL014
# 2     2021-12-15  2021  TX974690  Jamaica Beach    GAL014
# 3     2021-12-15  2021  TX974690  Jamaica Beach    GAL014
# 4     2021-12-01  2021  TX974690  Jamaica Beach    GAL014
# ...          ...   ...       ...            ...       ...
# 42535 2007-02-12  2007  TX669225     O'Neil Rd.    GAL062
# 42536 2007-01-29  2007  TX669225     O'Neil Rd.    GAL062
# 42537 2007-01-18  2007  TX669225     O'Neil Rd.    GAL062
# 42538 2007-01-02  2007  TX669225     O'Neil Rd.    GAL062
# 42539 2007-01-02  2007  TX669225     O'Neil Rd.    GAL062
#
#                StationName             Identifier    StartTime ZoneCode  \
# 0      Jamaica Beach South  GAL014_20211227_90752  09:00:00 AM      CDT
# 1      Jamaica Beach South  GAL014_20211227_90752  09:00:00 AM      CDT
# 2      Jamaica Beach South  GAL014_20211215_90599  09:00:00 AM      CDT
# 3      Jamaica Beach South  GAL014_20211215_90599  09:00:00 AM      CDT
# 4      Jamaica Beach South  GAL014_20211201_90435  09:00:00 AM      CDT
# ...                    ...                    ...          ...      ...
# 42535           O'Neil Rd.  GAL062_20070212_20485  06:30:00 AM      CDT
# 42536           O'Neil Rd.  GAL062_20070129_20308  06:00:00 AM      CDT
# 42537           O'Neil Rd.  GAL062_20070118_20214  06:00:00 AM      CDT
# 42538           O'Neil Rd.  GAL062_20070102_19969  06:00:00 AM      CDT
# 42539           O'Neil Rd.  GAL062_20070102_19969  06:00:00 AM      CDT
#
#        BacteriaCount ResultMeasureUnit ResultAnalyticalMethodIdentifier  \
# 0               7.94         MPN/100ml                            19299
# 1              20.00         MPN/100ml                            19299
# 2               6.30         MPN/100ml                            19299
# 3               5.00         MPN/100ml                            19299
# 4               7.07         MPN/100ml                            19299
# ...              ...               ...                              ...
# 42535          14.00         cfu/100ml                                -
# 42536           1.00         cfu/100ml                                -
# 42537           2.00         cfu/100ml                                -
# 42538           8.00         cfu/100ml                                -
# 42539          14.00         cfu/100ml                                -
#
#       ResultAnalyticalMethodName
# 0                     ENTEROLERT
# 1                     ENTEROLERT
# 2                     ENTEROLERT
# 3                     ENTEROLERT
# 4                     ENTEROLERT
# ...                          ...
# 42535                          -
# 42536                          -
# 42537                          -
# 42538                          -
# 42539                          -
#
# [42540 rows x 13 columns]

# %% [markdown]
# # Main Weather Station file

# %%
# Bianca's path - Read beach_attributes from local gdrive location, MUST BE CHANGED TO MATCH YOUR FILE LOCATION!!!
weather_station1_df= pd.read_csv("/content/drive/MyDrive/Data/WX Station/USW00012923.csv",skiprows=1)
weather_station1_df

# %%
# Drop null values.
weather_station1_df.dropna()

# %%
# Check the data types on each column
weather_station1_df.dtypes

# %%
# Renaming the columns to match the database schema.
renamed_weather_station1_df = weather_station1_df.rename(columns={"TAVG (Degrees Fahrenheit)":"AvgTemp", "TMAX (Degrees Fahrenheit)":"MaxTemp",
                                                        "TMIN (Degrees Fahrenheit)":"MinTemp", "PRCP (Inches)":"Precipitation",
                                                        "SNOW (Inches)":"Snowfall", "SNWD (Inches)":"SnowDepth"})

renamed_weather_station1_df

# %% [markdown]
# # Load
# ### Connect to the AWS RDS instance and write each DataFrame to its table.

# %%
# Create a function that loads the renamed_beach_attr_df
def load_renamed_beach_attr_df():

    # create the connection to the PostgreSQL database.
    password = getpass('Enter database password')
    db_string = f"postgresql://postgres1:{password}@final-project-database.crwsgvv9ibw0.us-east-1.rds.amazonaws.com:5432/final_project_db"
    engine = create_engine(db_string)
    renamed_beach_attr_df.to_sql(name="beach_attributes", con=engine, if_exists='replace', method='multi', index=False)

    # get the start_time from time.time()
    start_time = time.time()

    # add elapsed time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')

# %%
# Call load function
load_renamed_beach_attr_df()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     723         """
# --> 724         parts = [self.recv(flags, copy=copy, track=track)]
#     725         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-203-7be5c18044a5> in <module>()
#       1 # Call load function
# ----> 2 load_renamed_beach_attr_df()
#
# <ipython-input-202-b058b4401824> in load_renamed_beach_attr_df()
#       3
#       4     # create the connection to the PostgreSQL database.
# ----> 5     password = getpass('Enter database password')
#       6     db_string = f"postgresql://postgres1:{password}@final-project-database.crwsgvv9ibw0.us-east-1.rds.amazonaws.com:5432/final_project_db"
#       7     engine = create_engine(db_string)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#     685             self._parent_ident,
#     686             self._parent_header,
# --> 687             password=True,
#     688         )
#     689
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
# Create a function that loads the renamed_water_quality_df
def load_renamed_water_quality_df():
  
    # create the connection to the PostgreSQL database.
    password = getpass('Enter database password')
    db_string = f"postgresql://postgres1:{password}@final-project-database.crwsgvv9ibw0.us-east-1.rds.amazonaws.com:5432/final_project_db"
    engine = create_engine(db_string)
    renamed_water_quality_df.to_sql(name='water_quality', con=engine, if_exists='replace', method='multi', index=False)

    # get the start_time from time.time()
    start_time = time.time()

    # add elapsed time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')

# %%
# Call load function
load_renamed_water_quality_df()
# Out:
# Enter database password··········
# Done. 2.1457672119140625e-06 total seconds elapsed

# %%
# Create a function that loads the load_renamed_weather_station1_df
def load_renamed_weather_station1_df():

    # create the connection to the PostgreSQL database.
    password = getpass('Enter database password')
    db_string = f"postgresql://postgres1:{password}@final-project-database.crwsgvv9ibw0.us-east-1.rds.amazonaws.com:5432/final_project_db"
    engine = create_engine(db_string)
    renamed_weather_station1_df.to_sql(name='weather_station1', con=engine, if_exists='replace', method='multi', index=False)

    # get the start_time from time.time()
    start_time = time.time()

    # add elapsed time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')

# %%
# Call load function
load_renamed_weather_station1_df()
